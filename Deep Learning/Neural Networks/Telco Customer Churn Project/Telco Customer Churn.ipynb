# %% [markdown]
# # <a id='1'></a>
#
# <p style="
#     background: linear-gradient(to right, #11412D, #11424A);
#     font-family: 'Times New Roman', serif;
#     color: #F5C875;
#     font-size: 30px;
#     text-align: center;
#     border-radius: 12px;
#     padding: 12px;
#     border: 3px solid #F5C875;
#     box-shadow: 2px 2px 10px rgba(210, 180, 140, 0.5);
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     > > Telco Customer Churn Project < <
# </p>

# %% [markdown]
# - This dataset contains customer-level information from a
# telecommunications company.
# - The goal of this task is to analyze customer
# behavior and apply deep learning techniques to predict customer churn
# (whether a customer is likely to leave the service.)

# %% [markdown]
# | <p style="background-color:#114A3F;font-family:newtimeroman;color:#FFF9ED;font-size:100%;text-align:center;border-radius:10px; border: 2px solidrgb(98, 0, 255); padding: 10px;"> **Feature Name**</p> | <p style="background-color:#11424A;font-family:newtimeroman;color:#FFF9ED;font-size:100%;text-align:center;border-radius:10px; border: 2px solidrgb(98, 0, 255); padding: 10px;"> **Description**</p> |
# | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **customerID** | Unique identifier assigned to each customer.  |
# | **gender** | Gender of the customer.  |
# | **SeniorCitizen** |  Indicates whether the customer is a senior citizen (1 = Yes, 0 = No).   |
# | **Partner** | Indicates whether the customer has a partner.   |
# | **Churn** | Target variable indicating whether the customer left the company.  |
# | **TotalCharges** | Total amount charged to the customer over the entire tenure.   |
# | **MonthlyCharges** | Monthly amount charged to the customer.   |
# | **StreamingMovies** | Indicates whether movie streaming service is enabled.   |
# | **StreamingTV** | Indicates whether TV streaming service is enabled.   |
# | **TechSupport** | Indicates whether technical support service is enabled.   |
# | **DeviceProtection** | Indicates whether device protection service is enabled.  |
# | **OnlineBackup** | Indicates whether online backup service is enabled.  |
# | **OnlineSecurity** | Indicates whether online security service is enabled.  |
# | **InternetService** | Type of internet service subscribed by the customer.   |
# | **MultipleLines** | Indicates whether the customer has multiple phone lines.  |
# | **PhoneService** | Indicates whether the customer subscribes to phone service.  |
# | **PaymentMethod** | Payment method used by the customer to pay bills.  |
# | **PaperlessBilling** | Indicates whether the customer uses paperless billing.   |
# | **Contract** | Type of contract the customer has.  |
# | **tenure** | Number of months the customer has been with the company.  |
# | **Dependents** | Indicates whether the customer has dependents.  |

# %% [markdown]
# # <p style="background-color:#61451F;font-family:newtimeroman;color:#FBBB6D;font-size:75%;text-align:center;border-radius:10px; border: 2px solidrgb(98, 0, 255); padding: 3px;"> **Libraries**</p>

# %%
# Pandas : Data Manipulation
import pandas as pd


# NumPy : Math
import numpy as np
import math

import torch
import os
import random

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# MatPlotLib
import matplotlib
from matplotlib import style

import matplotlib.pyplot as plt

import seaborn as sns

import plotly.figure_factory as ff
import plotly.express as px
import plotly.graph_objects as go
from scipy.stats import skew


# Missing Value Imputation
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer


# handle imbalanced datasets
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline


# additional preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline


# Additional Metrics
from sklearn.metrics import log_loss, balanced_accuracy_score
from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_log_error


# Additional Statistical & Utility Imports
from scipy import stats
from scipy.stats import norm, boxcox
import warnings
warnings.filterwarnings('ignore')


# Spliting
from sklearn.model_selection import train_test_split


# Scaling
from sklearn.preprocessing import RobustScaler , MinMaxScaler , StandardScaler


# Encoding
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
# from category_encoders import OneHotEncoder,BinaryEncoder


# Correlation
# Feature Selection : Categorical
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest


# Feature Selection : Numerical
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import mutual_info_classif

# Feature Selection : Recursive Feature Elimination
from sklearn.feature_selection import RFE

# Advanced Feature Selection
from sklearn.feature_selection import SelectFromModel
from sklearn.inspection import permutation_importance
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.manifold import TSNE


# Model Selection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, StratifiedKFold, KFold
from sklearn.model_selection import RandomizedSearchCV


# Classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis


# regressors
from sklearn.ensemble import RandomForestRegressor , RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor , DecisionTreeClassifier
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression


# classifiers & regressors
from sklearn.neighbors import KNeighborsClassifier , KNeighborsRegressor
import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
# import lightgbm as lgb
# from lightgbm import LGBMClassifier, LGBMRegressor
# from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.ensemble import AdaBoostClassifier, AdaBoostRegressor
from sklearn.ensemble import BaggingClassifier, BaggingRegressor
from sklearn.ensemble import VotingClassifier, VotingRegressor
from sklearn.ensemble import StackingClassifier, StackingRegressor


# clustering
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN


# classification
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score , accuracy_score
from sklearn.metrics import confusion_matrix , classification_report


# regression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


# unsupervised
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score , adjusted_rand_score


# handle overfitting
from sklearn.linear_model import Ridge, Lasso


# Utility for saving models
import joblib
import pickle

# %% [markdown]
# # <p style="background-color:#1F6146;font-family:newtimeroman;color:#61F79B;font-size:75%;text-align:center;border-radius:10px; border: 2px solidrgb(98, 0, 255); padding: 3px;"> **Class** </p>

# %%
class MachineLearning:

  def data_information (self , data_frame):

    """
        Steps of understanding data to build the model ?

          Analysis :
            - plots of data frame for categorical & numerical
            - Some Math -> describe()

          Preprocessing :
            - Names of columns
            - Data types -> info() or here
            - nulls
            - duplicates
            - unique (num & values)
            - mean & median & mode : -> describe()
            - outliers -> box plot & math ( describe() )


    """


    """
        Just to know the information of each column.
        I get each name of it.
        Also each data type.
    """
    name_of_each_column = [col for col in data_frame]
    data_types_of_each_column = [data_frame[col].dtype for col in data_frame.columns]


    """
        Number of null values in each column is not enough to know if it is huge or not.
        I need to calculate the percentage of it based on length of data frame to make it clear.
    """
    null_values_of_each_column = [data_frame[col].isnull().sum() for col in data_frame.columns]
    percentage_of_null_values_of_each_column = [data_frame[col].isnull().sum() / len(data_frame) * 100 for col in data_frame.columns]


    """
        Unique values make me know :

          - What are the exact values of each column ?
          - Column is categorical or numerical ?

    """
    num_of_unique_values_of_each_column = [data_frame[col].nunique() for col in data_frame.columns]
    unique_values_of_each_column = [data_frame[col].unique() for col in data_frame.columns]


    """
        What are the num of duplicates in data frame ?
    """
    duplicates = data_frame.duplicated().sum()



    information_of_data = pd.DataFrame(
        {
            'Names' : name_of_each_column ,
            'Values' : unique_values_of_each_column ,
            'Data Type' : data_types_of_each_column ,
            'Unique Num' : num_of_unique_values_of_each_column ,
            'Null Num' : null_values_of_each_column ,
            'Null Percentage' : percentage_of_null_values_of_each_column ,
            'Duplicates' : duplicates
        }
    )

    return information_of_data
  
  
  def bar_plot(self , column , data_frame):
    sns.set_style("whitegrid")
    surviver_counts = data_frame[column].value_counts(normalize=True)*100

    plt.figure(figsize=(6, 6))
    ax = sns.barplot(x=surviver_counts.index, y=data_frame[column].value_counts(), palette="rocket")

    plt.title(f"Percentage of {column} and Non-{column}", fontsize=14, fontweight='bold')
    plt.xlabel(f"{column} Status", fontsize=12, fontweight='bold')
    plt.ylabel("Count", fontsize=12, fontweight='bold')

    for p, percentage in zip(ax.patches, surviver_counts.values):
      ax.annotate(f'{percentage:.1f}%',
                  (p.get_x() + p.get_width() / 2, p.get_height()),
                  ha='center', va='bottom',
                  fontsize=12, fontweight='bold', color='black')
    plt.show()
  
  
  def histogram_plot(self , column , data_frame):
    sns.set_style("whitegrid")
    plt.figure(figsize=(10, 6))

    skewness = skew(data_frame[column], nan_policy="omit")
    sns.histplot(data_frame[column], bins=50, kde=True, color="navy", edgecolor="black")

    plt.xlabel(column, fontsize=14, fontweight='bold')
    plt.ylabel("Frequency", fontsize=14, fontweight='bold')
    plt.title(f"Distribution of {column}", fontsize=16, fontweight='bold')

    plt.text(
        x=data_frame[column].max() * 0.7,
        y=plt.gca().get_ylim()[1] * 0.7,
        s=f"Skewness: {skewness:.2f}",
        fontsize=15, fontweight="bold", color="navy"
    )

    plt.show()
  
  
  def strip_plot(self , column_x , column_y , data_frame):
    plt.figure(figsize=(10, 6))
    sns.stripplot(x=data_frame[column_x], y=data_frame[column_y], jitter=True, alpha=0.7, palette=["#1f77b4", "#ff7f0e"])
    plt.xlabel(column_x, fontsize=14, fontweight="bold")
    plt.ylabel(column_y, fontsize=14, fontweight="bold")
    plt.title(f"Strip Plot of {column_y} by {column_x}", fontsize=16, fontweight="bold")
    plt.show()
  
  
  def pie_chart(self , column , data_frame):
    satisfaction_counts = data_frame[column].value_counts()

    plt.figure(figsize=(8, 6))
    plt.pie(satisfaction_counts,
            labels=satisfaction_counts.index,
            autopct='%1.1f%%',
            startangle=90,
            colors=plt.cm.Dark2.colors)

    plt.title(f"Distribution of {column}")
    plt.axis('equal')
    plt.show()
  
  
  def box_plot(self , column_x , column_y , data_frame):
    plt.figure(figsize=(10,5))
    sns.boxplot(x = column_x, y = column_y, data = data_frame, palette="rocket")

    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.title(f'Box Plot of {column_y} by {column_x}')
    plt.show()
  
  
  def count_plot(self , column , hue , data_frame):
    ax = sns.countplot(x = column , data=data_frame, palette='rocket',hue=hue)

    for p in ax.patches:
        height = p.get_height()
        if height > 0:
            ax.text(p.get_x() + p.get_width() / 2, height,
                    f'{height/len(data_frame)*100:.2f}%', ha='center', va='bottom', fontsize=10, color='black')

    plt.title(f'Count of {column} with {hue} Status')
    plt.show()
  
  
  def scatter_plot(self, x, y, hue, data_frame):
    ax = sns.scatterplot(x=x, y=y, data=data_frame, hue=hue, palette='rocket')
    plt.title(f'Scatter plot of {x} vs {y} by {hue}')
    plt.show()


  def heatmap(self, data_frame):
        corr = data_frame.corr()
        ax = sns.heatmap(corr, annot=True, cmap="rocket", fmt=".2f")
        plt.title("Correlation Heatmap")
        plt.show()


  def violin_plot(self, x, y, hue, data_frame):
        ax = sns.violinplot(x=x, y=y, data=data_frame, hue=hue, palette='rocket', split=True)
        plt.title(f'Violin plot of {y} across {x} grouped by {hue}')
        plt.show()


  def swarm_plot(self, x, y, hue, data_frame):
        sns.swarmplot(x=x, y=y, data=data_frame, hue=hue, palette='rocket', dodge=True)
        plt.title(f'Swarm plot of {y} across {x} grouped by {hue}')
        plt.show()


  def kde_plot(self, column, hue, data_frame):
        sns.kdeplot(data=data_frame, x=column, hue=hue, fill=True, palette='rocket')
        plt.title(f'KDE plot of {column} by {hue}')
        plt.show()


  def line_plot(self, x, y, hue, data_frame):
        sns.lineplot(x=x, y=y, data=data_frame, hue=hue, palette='rocket')
        plt.title(f'Line plot of {y} vs {x} by {hue}')
        plt.show()




  def pixal_bar_plot(self , data_frame , x , label_x , label_y , y = 'Count'):
    counts = data_frame[x].value_counts().reset_index()
    counts.columns = [x, y]

    fig = px.bar(counts, 
                x=x, 
                y=y, 
                title=f"Distribution of {x}",
                labels={x: label_x , 
                        y: label_y},
                color=y, 
                color_continuous_scale="ylgnbu")  

    fig.update_layout(
        title=dict(font=dict(size=24, family="Arial", color="black", weight="bold")),
        xaxis=dict(title_font=dict(size=20, family="Arial", color="black", weight="bold"), 
                  tickfont=dict(size=16, family="Arial", color="black")),
        yaxis=dict(title_font=dict(size=20, family="Arial", color="black", weight="bold"), 
                  tickfont=dict(size=16, family="Arial", color="black")),
        coloraxis_colorbar=dict(title_font=dict(size=16, family="Arial", color="black", weight="bold"))
    )

    fig.update_layout(xaxis_tickangle=-45)  
    fig.show()
    
    
    
  def another_bar_plot(self , data_frame , x , hue , labels_of_hue , y = 'Count'):
    counts = data_frame.groupby([x, hue]).size().unstack()
    counts.plot(kind='bar', stacked=True, figsize=(14, 6), color=['#1f77b4', '#ff7f0e'], edgecolor="black")
    
    plt.xlabel(x, fontsize=14, labelpad=10, fontweight="bold")
    plt.ylabel(y, fontsize=14, labelpad=10, fontweight="bold")
    plt.title(f"Distribution of {x}", fontsize=16, fontweight="bold")

    plt.legend(title=hue, labels=labels_of_hue)
    plt.show()


  def bar_pixel_plot(self , data_frame , x , hue ):
    grouped = pd.DataFrame(data_frame.groupby(x)[hue].value_counts()) 
    grouped = grouped.rename(columns={hue: 'Count'})
    grouped = grouped.reset_index()

    fig = px.histogram (grouped, x=x, y = 'count',
                        color=hue, barmode ='group', title="<b>"+f"{x} Vs {hue}", text_auto= True)

    fig.update_layout(
    title_font_color="black",
    template="plotly",
    title_font_size=30,
    title_x=0.5,
    xaxis_title=x,
    yaxis_title='count')

    fig.show()
  
  
  
  def for_each_type_bar_pixel_plot(self , data_frame , x , y ):
    fig=px.histogram (data_frame, x=x, facet_col=y, color=y, text_auto= True,
                      title="<b>"+f"{y} Vs {x}")
    fig.update_layout (hovermode='x', title_font_size=30)

    fig.update_layout(
    title_font_color="black",
    template="plotly",
    title_font_size=30,
    hoverlabel_font_size=20,
    title_x=0.5,
    xaxis_title=x,
    yaxis_title='count')

    fig.show()



  def grouped_features_relation_with_target_pixel_plot(self , data_frame , x , y , hue):
    fig = px.histogram(
    data_frame, 
    x=x, 
    y=y, 
    orientation="h", 
    color=hue,
    text_auto=True,
    title=f"<b>{x} Vs {y}",
    color_discrete_sequence=['#BA1F33', '#3A506B', '#3E885B']
    )

    fig.update_layout(
        hovermode='x',
        title_font_size=30,
        title_font_color="black",
        template="plotly",
        title_x=0.5,
        xaxis_title=x,
        yaxis_title=y,
        hoverlabel_font_size=20,
        bargap=0.3
    )

    fig.show()

  def handle_null_values(self , handling_type , columns , data_frame):

    # handling_type -> mode , mean (not prefered) , median , knn imputer

    if handling_type == 'mode' :

      for col in columns:
        # replace it with the most frequent value :
        data_frame[col] = data_frame[col].fillna( data_frame[col].mode()[0] )

    elif handling_type == 'knn imputer' :

      for col in columns:
        # replaces it with the previous value, and if it can't find it, then with the next one.
        data_frame[col] = data_frame[col].fillna(method='ffill').fillna(method='bfill')


    elif handling_type == 'median' :

      for col in columns :
        # replace it with the median because if the data is not normally distributed, the mean will be a problem.
        data_frame[col] = data_frame[col].fillna(data_frame[col].median())

    else :
      print("Invalid Value")



  def check_outliers(self, columns, data_frame, whis=1.5):
      n_cols = len(columns)
      
      # Calculate grid dimensions dynamically
      n_rows = (n_cols + 2) // 3  # Ceiling division for 3 columns per row
      n_cols_per_row = min(3, n_cols)  # Max 3 columns per row
      
      fig, axes = plt.subplots(n_rows, n_cols_per_row, 
                              figsize=(5 * n_cols_per_row, 5 * n_rows))
      axes = axes.flatten()
      
      for i, col in enumerate(columns):
          sns.boxplot(data=data_frame, y=col, ax=axes[i], palette='magma', whis=whis)
          axes[i].set_title(f'Boxplot of {col}', fontsize=12)
          axes[i].set_xlabel('')
          axes[i].set_ylabel(col)
      
      # Hide unused subplots
      for j in range(i + 1, len(axes)):
          fig.delaxes(axes[j])
      
      plt.tight_layout()
      plt.show()


  def handle_outliers(self , data_frame , column, upper_value = 1.5 , lower_value = 1.5 , handle = 'no'):

      for col in column:

          Q1=data_frame[col].quantile(0.25)
          Q3=data_frame[col].quantile(0.75)
          IQR=Q3-Q1

          lower_bound=Q1-(lower_value*IQR)
          upper_bound=Q3+(upper_value*IQR)

          outliers_mask_lower = (data_frame[col] < lower_bound)
          outliers_mask_upper = (data_frame[col] > upper_bound)
          outliers_count_lower = outliers_mask_lower.sum()
          outliers_count_upper = outliers_mask_upper.sum()
          print(f"Number of lower Outliers in {col} : {outliers_count_lower}")
          print(f"Number of upper Outliers in {col} : {outliers_count_upper}")

          if handle == 'yes' :
            data_frame[col]=np.where(data_frame[col]<lower_bound,lower_bound,data_frame[col])
            data_frame[col]=np.where(data_frame[col]>upper_bound,upper_bound,data_frame[col])

      return data_frame


  def scaling_data(self , scaler_type , data_frame , features_train , features_test , columns_list):

    if scaler_type == 'standard scaler':
      # Standard Scalar :
      standard_scaler = StandardScaler()
      features_train[columns_list] = standard_scaler.fit_transform(features_train[columns_list])
      features_test[columns_list] = standard_scaler.transform(features_test[columns_list])


    elif scaler_type == 'min max scaler':
      # Min Max Scalar :
      min_max_scaler = MinMaxScaler()
      features_train[columns_list] = min_max_scaler.fit_transform(features_train[columns_list])
      features_test[columns_list] = min_max_scaler.transform(features_test[columns_list])


    elif scaler_type == 'robust scaler':
      # Robust Scaler :
      robust_scaler = RobustScaler()
      features_train[columns_list] = robust_scaler.fit_transform(features_train[columns_list])
      features_test[columns_list] = robust_scaler.transform(features_test[columns_list])

    else:
      print("There is no scaler type with this name.")


    return features_train , features_test






  def ordinal_encoding_data(self , features_train , features_test , columns_list):

    # if encoding_type == 'label':

    #   label_encoding = LabelEncoder()
    #   features_train=label_encoding.fit_transform(features_train)
    #   features_test=label_encoding.transform(features_test)
      # handling unseen data
      
      all_categories = {}
      for col in columns_list:
          train_cats = features_train[col].unique()
          all_categories[col] = sorted(set(train_cats))

      ordinal_encoder = OrdinalEncoder(
          categories=[all_categories[col] for col in columns_list],
          handle_unknown='use_encoded_value',
          unknown_value=len(all_categories[col])
        )

      features_train[columns_list] = ordinal_encoder.fit_transform(features_train[columns_list])
      features_test[columns_list] = ordinal_encoder.transform(features_test[columns_list])

      return features_train , features_test





  def spliting_data(self , data_frame , label , test_size = 0.2 , random_state = 42):

    features = data_frame.drop([label],axis=1)
    target =data_frame[label]
    # random_state = 42 -> to make the split the same every time
    features_train , features_test , target_train , target_test = train_test_split(features, target, test_size=test_size, random_state=random_state)

    return features_train , features_test , target_train , target_test





  def correlation(self , features_train , target_train , data_frame , numerical_columns , categorical_columns):

    # Numerical : anova
    x = features_train[numerical_columns]
    y = target_train

    f_values, p_values = f_classif(x, y)

    numerical_anova_data_frame = pd.DataFrame({
        'Feature': numerical_columns,
        'F-Score': f_values,
        'P-Value': p_values
    }).sort_values(by='F-Score', ascending=False)


    # # Categorical : chi2
    x=features_train[categorical_columns]
    y=target_train

    # chi2_selector = SelectKBest(score_func=chi2, k='all')
    # chi2_selector.fit(x, y)
    # categorical_chi2_data_frame = pd.DataFrame({
    #     'Feature': x.columns,
    #     'Chi2 Score': chi2_selector.scores_,
    #     'P-Value': chi2_selector.pvalues_
    # }).sort_values(by='Chi2 Score', ascending=False)
     # Create results DataFrame
    mi_scores = mutual_info_classif(x, y, random_state=42)
    mi_data_frame = pd.DataFrame({
        'Feature': x.columns,
        'MI_Score': mi_scores
    }).sort_values(by='MI_Score', ascending=False)
    
    # Separate if needed
    numerical_mi = mi_data_frame[mi_data_frame['Feature'].isin(numerical_columns)]
    categorical_mi = mi_data_frame[mi_data_frame['Feature'].isin(categorical_columns)]

    return numerical_anova_data_frame , mi_data_frame





  def best_parameters(self , text , model_type , params , model , x_train, x_test, y_train, y_test):

    result = {}

    # grid Search : to find the best hyperparameters
    grid = GridSearchCV(
      # random_state = 42 -> same initial weights for comparsion
        estimator = model,
        # what parameters to try
        param_grid = params,
        # cross validation
        cv=5,
        # get the accuracy
        scoring='accuracy',
        # run on cpu
        n_jobs=-1,

        verbose=1
    )

    grid.fit(x_train, y_train)

    # best_estimator_ : returns the model with the best hyperparameters found during grid search
    best = grid.best_estimator_
    result[f'Best {text} Model'] = best

    y_train_pred = best.predict(x_train)

    y_test_pred = best.predict(x_test)

    if model_type == 'classification':
      # calculate metrics -> accuracy , precision , recall , f1 , auc
      metrics_train = {
          # accuracy : (TP + TN) / (TP + TN + FP + FN)
          'accuracy': accuracy_score(y_train, y_train_pred),
          # precision : TP / (TP + FP)
          'precision': precision_score(y_train, y_train_pred),
          # recall : TP / (TP + FN)
          'recall': recall_score(y_train, y_train_pred),
          # f1 score : 2 * (precision * recall) / (precision + recall)
          'f1': f1_score(y_train, y_train_pred),
          # auc : area under the roc curve
          'auc': roc_auc_score(y_train, y_train_pred),
          # best parameters from grid search
          'best_params': grid.best_params_
      }
      metrics_test = {
          'accuracy': accuracy_score(y_test, y_test_pred),
          'precision': precision_score(y_test, y_test_pred),
          'recall': recall_score(y_test, y_test_pred),
          'f1': f1_score(y_test, y_test_pred),
          'auc': roc_auc_score(y_test, y_test_pred),
          'best_params': grid.best_params_
      }
      print(f"Best {text}")
      print(f"Best Parameters: {grid.best_params_}")
      print("Accuracies are based on Accuracy Score:")
      print(f"Train Accuracy: {metrics_train['accuracy']:.4f}")
      print(f"Test Accuracy: {metrics_test['accuracy']:.4f}")


    elif model_type == 'regression':
      metrics_train = {
          # R² : proportion of variance explained by the model
          'r2': r2_score(y_train, y_train_pred),
          # MAE : mean absolute error
          'mae': mean_absolute_error(y_train, y_train_pred),
          # MSE : mean squared error
          'mse': mean_squared_error(y_train, y_train_pred),
          # RMSE : root mean squared error
          'rmse': np.sqrt(mean_squared_error(y_train, y_train_pred)),
          # best parameters from grid search
          'best_params': grid.best_params_
      }
      metrics_test = {
          'r2': r2_score(y_test, y_test_pred),
          'mae': mean_absolute_error(y_test, y_test_pred),
          'mse': mean_squared_error(y_test, y_test_pred),
          'rmse': np.sqrt(mean_squared_error(y_test, y_test_pred)),
          'best_params': grid.best_params_
      }
      print(f"Best {text}")
      print(f"Best Parameters: {grid.best_params_}")
      print("Accuracies are based on R² Score:")
      print(f"Train Accuracy: {metrics_train['r2']:.4f}")
      print(f"Test Accuracy: {metrics_test['r2']:.4f}")


    elif model_type == 'unsupervised':
      # calculate metrics -> silhouette , davies-bouldin , calinski-harabasz
      metrics_train = {
          # silhouette : cohesion vs separation (-1 to 1, higher is better)
          'silhouette': silhouette_score(x_train, y_train_pred),
          # davies-bouldin : average similarity between clusters (lower is better)
          'davies_bouldin': davies_bouldin_score(x_train, y_train_pred),
          # calinski-harabasz : ratio of between-cluster dispersion to within-cluster dispersion (higher is better)
          'calinski_harabasz': calinski_harabasz_score(x_train, y_train_pred),
          # best parameters from grid search
          'best_params': grid.best_params_
      }
      metrics_test = {
          'silhouette': silhouette_score(x_test, y_test_pred),
          'davies_bouldin': davies_bouldin_score(x_test, y_test_pred),
          'calinski_harabasz': calinski_harabasz_score(x_test, y_test_pred),
          'best_params': grid.best_params_
      }
      print(f"Best {text}")
      print(f"Best Parameters: {grid.best_params_}")
      print("Accuracies are based on Silhouette Score:")
      print(f"Train Accuracy: {metrics_train['silhouette']:.4f}")
      print(f"Test Accuracy: {metrics_test['silhouette']:.4f}")



    result[f'{text} Train Metrics'] = metrics_train
    result[f'{text} Test Metrics'] = metrics_test

    return result





  def train_test_evaluate(self , scaler_type , x_train , x_test , y_train , y_test , model):

    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    y_pred_train = model.predict(x_train)
    print(f"{scaler_type} Scaler")
    print("Train Accuracy:", accuracy_score(y_train, y_pred_train))
    print("Test Accuracy:", accuracy_score(y_test, y_pred))





  def evaluate_classification(self , y_test, y_pred, labels=None):
      # Metrics
      acc = accuracy_score(y_test, y_pred)
      prec = precision_score(y_test, y_pred, average="weighted")
      rec = recall_score(y_test, y_pred, average="weighted")
      f1 = f1_score(y_test, y_pred, average="weighted")

      print(f"Accuracy: {acc:.4f}")
      print(f"Precision: {prec:.4f}")
      print(f"Recall: {rec:.4f}")
      print(f"F1 Score: {f1:.4f}")
      print("\nClassification Report:\n", classification_report(y_test, y_pred))

      # Confusion Matrix
      cm = confusion_matrix(y_test, y_pred)
      plt.figure(figsize=(6,4))
      sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                  xticklabels=labels, yticklabels=labels)
      plt.xlabel("Predicted")
      plt.ylabel("Actual")
      plt.title("Confusion Matrix")
      plt.show()





  def evaluate_regression(self , y_test, y_pred):
      mae = mean_absolute_error(y_test, y_pred)
      mse = mean_squared_error(y_test, y_pred)
      rmse = np.sqrt(mse)
      r2 = r2_score(y_test, y_pred)

      print(f"MAE: {mae:.4f}")
      print(f"MSE: {mse:.4f}")
      print(f"RMSE: {rmse:.4f}")
      print(f"R² Score: {r2:.4f}")




  def evaluate_clustering(self , X, labels, true_labels=None):
      # Internal metrics (no ground truth needed)
      sil = silhouette_score(X, labels)
      db = davies_bouldin_score(X, labels)

      print(f"Silhouette Score: {sil:.4f}")
      print(f"Davies-Bouldin Index: {db:.4f}")

      # External metric (only if true labels are available)
      if true_labels is not None:
          ari = adjusted_rand_score(true_labels, labels)
          print(f"Adjusted Rand Index (vs true labels): {ari:.4f}")

# %% [markdown]
# Categorical plots: count, bar, box, violin, strip, swarm
#
# Distribution plots: hist, kde, violin
#
# Relational plots: scatter, line, joint, pair
#
# Matrix plots: heatmap

# %% [markdown]
# # <p style="background-color:#61451F;font-family:newtimeroman;color:#FBBB6D;font-size:75%;text-align:center;border-radius:10px; border: 2px solidrgb(98, 0, 255); padding: 3px;"> **Parameters Guide**</p>

# %% [markdown]
# #### **Regression**

# %%
ridge = {
    'alpha': [0.01, 0.1, 1, 10],
    # 'solver': ['auto', 'svd', 'cholesky'],
}

# %%
lasso = {
    'alpha': [0.01, 0.1, 1, 10],
    # 'max_iter': [1000, 2000],
}

# %% [markdown]
# #### **Classification**

# %%
logistic_regression = {
    'C': [0.01, 0.1, 1, 10],   # Regularization strength (smaller = stronger regularization)
    'penalty': ['l1', 'l2', 'elasticnet', 'none'], # l1 = Lasso (feature selection), l2 = Ridge (spread error)
    'solver': ['saga' , 'liblinear'],  # saga supports l1, l2, elasticnet
    # 'class_weight': [None, 'balanced'], # Handle class imbalance
    # 'max_iter': [100, 200, 500],  # less critical
}

# %%
xg_boost = {
    'n_estimators': [100, 200, 500],  # Number of boosting rounds
    'learning_rate': [0.01, 0.1, 0.2], # Step size shrinkage
    'max_depth': [3, 5, 7],           # Tree depth
    'subsample': [0.8, 1.0],          # Fraction of samples
    'colsample_bytree': [0.8, 1.0],   # Fraction of features per tree
    'gamma': [0, 0.1, 0.5]            # Minimum loss reduction for split
}

# %%
naive_bayes_or_GaussianNB = {
    'var_smoothing': [1e-09, 1e-08, 1e-07] # Stability parameter to avoid division by zero
}

# %% [markdown]
# #### **Supervised**

# %%
support_vector_machine = {
    'C': [0.1, 1, 10],                # Regularization strength
    'kernel': ['linear', 'rbf', 'poly'], # Kernel type
    'gamma': ['scale', 'auto'],       # Kernel coefficient (rbf/poly)
    # 'class_weight': [None, 'balanced'] # Handle imbalance
    # 'degree': [2, 3, 4]
}

# %%
decision_tree = {
    'criterion': ['gini', 'entropy'], # Split quality measure
    'max_depth': [None, 5, 10, 20],   # Limit depth to avoid overfitting
    'min_samples_split': [2, 5, 10],  # Minimum samples to split a node
    'min_samples_leaf': [1, 2, 4],    # Minimum samples per leaf
    'class_weight': [None, 'balanced'] # Handle imbalance
}

# %%
random_forest = {
    'n_estimators': [100, 200, 500],  # Number of trees
    'criterion': ['gini', 'entropy'], # Split quality measure
    'max_depth': [None, 10, 20],      # Tree depth
    'min_samples_split': [2, 5, 10],  # Minimum samples to split
    'min_samples_leaf': [1, 2, 4],    # Minimum samples per leaf
    # 'bootstrap': [True, False],       # Whether to use bootstrapped samples
    # 'class_weight': [None, 'balanced'] # Handle imbalance
}

# %%
k_nearest_neighbors  = {
    'n_neighbors': [3, 5, 7, 11],     # Number of neighbors
    'weights': ['uniform', 'distance'], # Uniform = equal weight, distance = closer neighbors matter more
    'metric': ['euclidean', 'manhattan', 'minkowski'] # Distance metric
}

# %%
gradient_boosting = {
    'n_estimators': [100, 200, 500],  # Number of boosting stages
    'learning_rate': [0.01, 0.1, 0.2], # Shrinks contribution of each tree
    'max_depth': [3, 5, 7],           # Depth of individual trees
    'min_samples_split': [2, 5, 10],  # Minimum samples to split
    'min_samples_leaf': [1, 2, 4]     # Minimum samples per leaf
    # 'subsample': [0.8, 1.0]          # Fraction of samples used per tree
}

# %% [markdown]
# #### **Unsupervised**

# %%
kmeans = {
    'n_clusters': [2, 3, 5, 10],
    'init': ['k-means++', 'random'],
    'n_init': [10, 20],
    # 'max_iter': [300, 500],
}

# %%
agglomerative_clustering = {
    'n_clusters': [2, 3, 5, 10],
    'linkage': ['ward', 'complete', 'average'],
    # 'affinity': ['euclidean', 'manhattan'],
}

# %%
dbscan = {
    'eps': [0.3, 0.5, 1.0],
    'min_samples': [5, 10],
    # 'metric': ['euclidean', 'manhattan'],
}

# %% [markdown]
# # <p style="background-color:#1F6146;font-family:newtimeroman;color:#61F79B;font-size:75%;text-align:center;border-radius:10px; border: 2px solidrgb(98, 0, 255); padding: 3px;"> **Code**</p>

# %%
def set_all_seeds(seed=42):

    random.seed(seed)
    
    np.random.seed(seed)
    
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if using multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    tf.random.set_seed(seed)

set_all_seeds(42)

# %% [markdown]
# ## <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #805D2C);
#     font-family: 'Times New Roman', serif;
#     color: #FFD6A0;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 4px;
#     box-shadow: 2px 2px 10px #452F1AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Loading Data
# </p>

# %%
# install openpyxl for reading .xlsx files
# %pip install openpyxl --quiet

# load dataset (explicit engine to ensure openpyxl is used)
data_frame = pd.read_excel(r"E:\AI\Robo\content\Study\drive-download-20260130T175619Z-3-002\Session 6\Telco_Customer_Churn\Telco_customer_churn.xlsx", engine="openpyxl")
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
algorithm = MachineLearning()

# %% [markdown]
# ## <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #318462);
#     font-family: 'Times New Roman', serif;
#     color: #FFD6A0;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 4px;
#     box-shadow: 2px 2px 10px #452F1AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Information About Data
# </p>

# %%
data_frame.shape
# Out:
# (7043, 33)

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
algorithm.data_information(data_frame)
# Out:
#                 Names                                             Values  \
# 0          CustomerID  [3668-QPYBK, 9237-HQITU, 9305-CDSKC, 7892-POOK...
# 1               Count                                                [1]
# 2             Country                                    [United States]
# 3               State                                       [California]
# 4                City  [Los Angeles, Beverly Hills, Huntington Park, ...
# 5            Zip Code  [90003, 90005, 90006, 90010, 90015, 90020, 900...
# 6            Lat Long  [33.964131, -118.272783, 34.059281, -118.30742...
# 7            Latitude  [33.964131, 34.059281, 34.048013, 34.062125, 3...
# 8           Longitude  [-118.272783, -118.30742, -118.293953, -118.31...
# 9              Gender                                     [Male, Female]
# 10     Senior Citizen                                          [No, Yes]
# 11            Partner                                          [No, Yes]
# ...

# %%
print(data_frame.isnull().sum().sum())
# Out:
# 5174

# %%
data_frame.describe().T.style.bar(subset=['mean'], color='#FFA07A').background_gradient(
    subset=['std', '50%', 'max'], cmap='Blues').set_properties(
        **{'font-size': '12pt', 'border': '1.5px solid black'}).set_caption("🔍 Summary Statistics of the Dataset")
# Out:
# <style type="text/css">
# #T_a1c4c_row0_col0, #T_a1c4c_row0_col3, #T_a1c4c_row0_col4, #T_a1c4c_row0_col6, #T_a1c4c_row1_col0, #T_a1c4c_row1_col3, #T_a1c4c_row1_col4, #T_a1c4c_row1_col6, #T_a1c4c_row2_col0, #T_a1c4c_row2_col3, #T_a1c4c_row2_col4, #T_a1c4c_row2_col6, #T_a1c4c_row3_col0, #T_a1c4c_row3_col3, #T_a1c4c_row3_col4, #T_a1c4c_row3_col6, #T_a1c4c_row4_col0, #T_a1c4c_row4_col3, #T_a1c4c_row4_col4, #T_a1c4c_row4_col6, #T_a1c4c_row5_col0, #T_a1c4c_row5_col3, #T_a1c4c_row5_col4, #T_a1c4c_row5_col6, #T_a1c4c_row6_col0, #T_a1c4c_row6_col3, #T_a1c4c_row6_col4, #T_a1c4c_row6_col6, #T_a1c4c_row7_col0, #T_a1c4c_row7_col3, #T_a1c4c_row7_col4, #T_a1c4c_row7_col6, #T_a1c4c_row8_col0, #T_a1c4c_row8_col3, #T_a1c4c_row8_col4, #T_a1c4c_row8_col6 {
#   font-size: 12pt;
#   border: 1.5px solid black;
# }
# #T_a1c4c_row0_col1, #T_a1c4c_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.1%, #FFA07A 0.1%, #FFA07A 0.1%, transparent 0.1%);
#   font-size: 12pt;
# ...

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Data Overview Insights
# </p>

# %%
algorithm.data_information(data_frame)
# Out:
#                 Names                                             Values  \
# 0          CustomerID  [3668-QPYBK, 9237-HQITU, 9305-CDSKC, 7892-POOK...
# 1               Count                                                [1]
# 2             Country                                    [United States]
# 3               State                                       [California]
# 4                City  [Los Angeles, Beverly Hills, Huntington Park, ...
# 5            Zip Code  [90003, 90005, 90006, 90010, 90015, 90020, 900...
# 6            Lat Long  [33.964131, -118.272783, 34.059281, -118.30742...
# 7            Latitude  [33.964131, 34.059281, 34.048013, 34.062125, 3...
# 8           Longitude  [-118.272783, -118.30742, -118.293953, -118.31...
# 9              Gender                                     [Male, Female]
# 10     Senior Citizen                                          [No, Yes]
# 11            Partner                                          [No, Yes]
# ...

# %% [markdown]
# 1. Shape of data set is 7043 rows & 33 columns.
#
# 2. Nulls are 5174 null values
#    - all null values in the churn reason feature -> 73.46 % of its values are null (will absoluty be deleted)
#
# 3. there are 6 integer columns + 3 float columns + 24 object(ليه بجد) :
#
#    - Churn Value : Target Column has values
#      - 0 : customer stayed (retained) -> 73.463%
#      - 1 : customer left (churned) -> 26.5370%
#      - class imbalance
#
# 4. Features Information
#
#   - CustomerID : large number of unique values that equal to the number of data set rows so it will be deleted -> object
#
#   Very Unuseful Feature , all values are the same : will be deleted
#   - Count(1) , it will be deleted -> int
#   - Country(United States) -> object
#   - State(California)  -> object
#     *After deleting them , There are no duplicates*
#
#   - need encoding
#     - Gender(2)
#     - Senior Citizen(2)
#     - Partner(2)
#     - Dependents(2)
#     - Phone Service(2)
#     - Paperless Billing(2)
#     - Churn Label(2)
#
#     - Multiple Lines(3)
#     - Internet Service(3)
#     - Online Security(3)
#     - Online Backup(3)
#     - Device Protection(3)
#     - Tech Support(3)
#     - Streaming TV(3)
#     - Streaming Movies(3)
#     - Contract(3)
#
#     - Payment Method(4)
#
#     - Churn Reason(20) -> will be deleted bec of number of null values
#
#     - City : large number of unique values! (1129) -> (may be deleted)
#     - Lat Long : large number of unique values! (1652) -> (may be deleted) , want to try change the type to check if all its values are numbers ?
#     - Total Charges : large number of unique values! (6531) -> (may be deleted), want to try change the type to check if all its values are numbers ?
#
#   - need scaling
#     - Zip Code
#     - Latitude
#     - Longitude
#     - Monthly Charges
#     - Tenure Months
#     - Churn Score
#     - CLTV
#
#   do not think there are columns need handling outliers , but i will check it for numberical columns

# %% [markdown]
# ## <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #805D2C);
#     font-family: 'Times New Roman', serif;
#     color: #FFD6A0;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 4px;
#     box-shadow: 2px 2px 10px #452F1AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Data Analysis
# </p>

# %%
algorithm.pie_chart('Churn Value' , data_frame)

# %%
algorithm.pie_chart('Senior Citizen' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Senior Citizen' , 'Churn Value')

# %% [markdown]
# that actually not a reason for customers to left , percentage of senior citizen is small already

# %%
algorithm.pie_chart('Gender' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Gender' , 'Churn Value')

# %% [markdown]
# - female customers that left is really close to male & the percentage of female customers is so close to male customers.
# - there is something imacting both male and female customers in the same way

# %%
algorithm.pie_chart('Partner' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Partner' , 'Churn Value')

# %% [markdown]
# most of customers that left do not have partners.

# %%
algorithm.pie_chart('Dependents' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Dependents' , 'Churn Value')

# %% [markdown]
# - ok , no of customers has dependents less than others
# - and no of customers that left and has dependents is less than that left and does not have dependents

# %%
algorithm.histogram_plot('Tenure Months' , data_frame)
algorithm.box_plot('Churn Value' , 'Tenure Months' , data_frame)

# %% [markdown]
# - most of the customers that left company has small number of months been with it.
# - This might mean that there aren't enough things to attract the customer at the beginning of beening with this company, and that we need to find different ways to grab their attention more.

# %%
algorithm.pie_chart('Contract' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Contract' , 'Churn Value')

# %% [markdown]
# - ok , the percentage of the customers that have two year contract is 24.1% but that contract type is the most good one for most of the its customers
# - i think if the percentage of that type is the highest , the number of customers that will leave will decrease

# %%
algorithm.pie_chart('Paperless Billing' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Paperless Billing' , 'Churn Value')

# %% [markdown]
# the less paperless billing is used , the more customers will remain

# %%
algorithm.pie_chart('Payment Method' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Payment Method' , 'Churn Value')

# %% [markdown]
# the worst payment way is by electronic check

# %%
algorithm.pie_chart('Phone Service' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Phone Service' , 'Churn Value')

# %%
algorithm.pie_chart('Multiple Lines' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Multiple Lines' , 'Churn Value')

# %% [markdown]
# that is not a reason , it does not matter if customer has multiple lines or not the result is very close

# %%
algorithm.pie_chart('Internet Service' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Internet Service' , 'Churn Value')

# %% [markdown]
# fiber is not a good internet service

# %%
algorithm.pie_chart('Online Security' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Online Security' , 'Churn Value')

# %% [markdown]
# most of customers that left have no online security

# %%
algorithm.pie_chart('Online Backup' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Online Backup' , 'Churn Value')

# %% [markdown]
# most of customers that left have no online back up

# %%
algorithm.pie_chart('Tech Support' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Tech Support' , 'Churn Value')

# %% [markdown]
# most of customers that left have no online tech support

# %%
algorithm.pie_chart('Streaming TV' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Streaming TV' , 'Churn Value')

# %% [markdown]
# not a reason to left

# %%
algorithm.pie_chart('Streaming Movies' , data_frame)
algorithm.bar_pixel_plot(data_frame , 'Streaming Movies' , 'Churn Value')

# %% [markdown]
# not a reason to left

# %%
algorithm.histogram_plot('Monthly Charges' , data_frame)
algorithm.box_plot('Churn Value' , 'Monthly Charges' , data_frame)

# %%
data_frame['Monthly Charges'].value_counts()
# Out:
# Monthly Charges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 19.70     43
#           ..
# 81.60      1
# 91.60      1
# 112.75     1
# 34.85      1
# 61.75      1
# Name: count, Length: 1585, dtype: int64

# %%
low_threshold = data_frame['Monthly Charges'].quantile(0.01)
print(low_threshold)
print(data_frame[data_frame['Monthly Charges'] < low_threshold]['Monthly Charges'].value_counts())
# Out:
# 19.2
# Monthly Charges
# 19.10    12
# 19.15    11
# 19.05     9
# 18.80     7
# 19.00     7
# 18.95     6
# 18.85     5
# 18.70     2
# 18.90     2
# 18.40     1
# 18.25     1
# 18.75     1
# 18.55     1
# Name: count, dtype: int64

# %% [markdown]
# - Too many low-paying customers
# - only 1% of customers pay less than $19.2/month
# - log transform

# %% [markdown]
# ## <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #318462);
#     font-family: 'Times New Roman', serif;
#     color: #FFD6A0;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 4px;
#     box-shadow: 2px 2px 10px #452F1AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Preprocessing
# </p>

# %%
algorithm.data_information(data_frame)
# Out:
#                 Names                                             Values  \
# 0          CustomerID  [3668-QPYBK, 9237-HQITU, 9305-CDSKC, 7892-POOK...
# 1               Count                                                [1]
# 2             Country                                    [United States]
# 3               State                                       [California]
# 4                City  [Los Angeles, Beverly Hills, Huntington Park, ...
# 5            Zip Code  [90003, 90005, 90006, 90010, 90015, 90020, 900...
# 6            Lat Long  [33.964131, -118.272783, 34.059281, -118.30742...
# 7            Latitude  [33.964131, 34.059281, 34.048013, 34.062125, 3...
# 8           Longitude  [-118.272783, -118.30742, -118.293953, -118.31...
# 9              Gender                                     [Male, Female]
# 10     Senior Citizen                                          [No, Yes]
# 11            Partner                                          [No, Yes]
# ...

# %%
numerical_columns = ['Zip Code' , 'Latitude' , 'Longitude', 'Tenure Months' , 'Monthly Charges' , 'Churn Score' , 'CLTV']
categorical_columns = ['City','Gender','Senior Citizen','Partner','Dependents','Phone Service','Multiple Lines','Internet Service',
                    'Online Security','Online Backup','Device Protection','Tech Support','Streaming TV','Streaming Movies','Contract',
                    'Paperless Billing','Payment Method','Total Charges','left_for_competitor','left_for_price','left_for_service']

irrelevant_columns = ['CustomerID' , 'Count' , 'Country' , 'State']

try_change_type = ['Lat Long' , 'Total Charges']

churn_reason_column = data_frame['Churn Reason']
# will be removed
null_columns = ['Churn Reason']

outliers_columns = ['Zip Code' , 'Latitude' , 'Longitude', 'Tenure Months' , 'Monthly Charges' , 'Churn Score' , 'CLTV']

encoding_columns_small = ['Gender' , 'Senior Citizen' , 'Partner' , 'Dependents' , 'Phone Service' , 'Paperless Billing' , 'Multiple Lines' , 'Internet Service' , 'Online Security' , 
'Online Backup' , 'Device Protection' , 'Tech Support' , 'Streaming TV' , 'Streaming Movies' , 'Contract' , 'Payment Method']

encoding_columns_large = ['City' , 'Lat Long' , 'Total Charges']

scaling_columns = ['Zip Code' , 'Latitude' , 'Longitude', 'Tenure Months' , 'Monthly Charges' , 'Churn Score' , 'CLTV']

# %%
data_frame = data_frame.drop('CustomerID' , axis=1)
data_frame = data_frame.drop('State' , axis=1)
data_frame = data_frame.drop('Count' , axis=1)
data_frame = data_frame.drop('Country' , axis=1)
data_frame = data_frame.drop('Churn Label' , axis=1)

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Nulls
# </p>

# %%
data_frame = data_frame.drop('Churn Reason' , axis=1)

# %%
algorithm.data_information(data_frame)
# Out:
#                 Names                                             Values  \
# 0                City  [Los Angeles, Beverly Hills, Huntington Park, ...
# 1            Zip Code  [90003, 90005, 90006, 90010, 90015, 90020, 900...
# 2            Lat Long  [33.964131, -118.272783, 34.059281, -118.30742...
# 3            Latitude  [33.964131, 34.059281, 34.048013, 34.062125, 3...
# 4           Longitude  [-118.272783, -118.30742, -118.293953, -118.31...
# 5              Gender                                     [Male, Female]
# 6      Senior Citizen                                          [No, Yes]
# 7             Partner                                          [No, Yes]
# 8          Dependents                                          [No, Yes]
# 9       Tenure Months  [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...
# 10      Phone Service                                          [Yes, No]
# 11     Multiple Lines                        [No, Yes, No phone service]
# ...

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #2C210D);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #45311AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Data Type Inspection
# </p>

# %%
# for col in try_change_type:
#     data_frame[col] = data_frame[col].astype(float)

# data_frame['Lat Long'].unique()

# data_frame[['Latitude', 'Longitude']] = data_frame['Lat Long'].str.split(', ', expand=True).astype(float)
# print(data_frame['Latitude'].unique())
# print(data_frame['Longitude'].unique())
data_frame = data_frame.drop('Lat Long' , axis = 1)

# %%
data_frame['Total Charges'].unique()

data_frame['Total Charges'] = pd.to_numeric(data_frame['Total Charges'], errors='coerce')

# def converting(value):
#     if pd.isna(value):
#         return np.nan
#     value_str = str(value).strip()
#     if value_str == '' or value_str.isspace():
#         return np.nan
    
# data_frame['Total Charges'] = data_frame['Total Charges'].apply(converting)
print(data_frame['Total Charges'].isnull().sum())
print(data_frame['Total Charges'].unique())
print(data_frame['Total Charges'].dtype)
# data_frame['Total Charges'] = data_frame['Total Charges'].astype(float)
# Out:
# 11
# [ 108.15  151.65  820.5  ... 7362.9   346.45 6844.5 ]
# float64

# %%
algorithm.handle_null_values('median' , ['Total Charges'] , data_frame)

# %%
data_frame['Total Charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
numerical_columns = numerical_columns + ['Latitude' , 'Longitude' , 'Total Charges']
scaling_columns = scaling_columns + ['Latitude' , 'Longitude' , 'Total Charges']
outliers_columns = outliers_columns + ['Latitude' , 'Longitude' , 'Total Charges']

# %%
algorithm.data_information(data_frame)
# Out:
#                 Names                                             Values  \
# 0                City  [Los Angeles, Beverly Hills, Huntington Park, ...
# 1            Zip Code  [90003, 90005, 90006, 90010, 90015, 90020, 900...
# 2            Latitude  [33.964131, 34.059281, 34.048013, 34.062125, 3...
# 3           Longitude  [-118.272783, -118.30742, -118.293953, -118.31...
# 4              Gender                                     [Male, Female]
# 5      Senior Citizen                                          [No, Yes]
# 6             Partner                                          [No, Yes]
# 7          Dependents                                          [No, Yes]
# 8       Tenure Months  [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...
# 9       Phone Service                                          [Yes, No]
# 10     Multiple Lines                        [No, Yes, No phone service]
# 11   Internet Service                             [DSL, Fiber optic, No]
# ...

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Outliers
# </p>

# %%
outliers_columns
# Out:
# ['Zip Code',
#  'Latitude',
#  'Longitude',
#  'Tenure Months',
#  'Monthly Charges',
#  'Churn Score',
#  'CLTV',
#  'Latitude',
#  'Longitude',
#  'Total Charges']

# %%
algorithm.check_outliers(outliers_columns , data_frame)

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #2C210D);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #45311AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Feature Engineering
# </p>

# %%
data_frame['left_for_competitor'] = churn_reason_column.str.contains('Competitor', na=False).astype(int)
data_frame['left_for_price'] = churn_reason_column.str.contains('Price|charges', case=False, na=False).astype(int)
data_frame['left_for_service'] = churn_reason_column.str.contains('service|support', case=False, na=False).astype(int)

# %%
data_frame['Monthly Charges log'] = np.log1p(data_frame['Monthly Charges'])

# %%
algorithm.data_information(data_frame)
# Out:
#                   Names                                             Values  \
# 0                  City  [Los Angeles, Beverly Hills, Huntington Park, ...
# 1              Zip Code  [90003, 90005, 90006, 90010, 90015, 90020, 900...
# 2              Latitude  [33.964131, 34.059281, 34.048013, 34.062125, 3...
# 3             Longitude  [-118.272783, -118.30742, -118.293953, -118.31...
# 4                Gender                                     [Male, Female]
# 5        Senior Citizen                                          [No, Yes]
# 6               Partner                                          [No, Yes]
# 7            Dependents                                          [No, Yes]
# 8         Tenure Months  [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...
# 9         Phone Service                                          [Yes, No]
# 10       Multiple Lines                        [No, Yes, No phone service]
# ...

# %%
numerical_columns = numerical_columns + ['Monthly Charges log']
scaling_columns = scaling_columns + ['Monthly Charges log']
outliers_columns = outliers_columns + ['Monthly Charges log']

# %%
data_frame[numerical_columns]
# Out:
#       Zip Code   Latitude   Longitude  Tenure Months  Monthly Charges  \
# 0        90003  33.964131 -118.272783              2            53.85
# 1        90005  34.059281 -118.307420              2            70.70
# 2        90006  34.048013 -118.293953              8            99.65
# 3        90010  34.062125 -118.315709             28           104.80
# 4        90015  34.039224 -118.266293             49           103.70
# ...        ...        ...         ...            ...              ...
# 7038     92285  34.341737 -116.539416             72            21.15
# 7039     92301  34.667815 -117.536183             24            84.80
# 7040     92304  34.559882 -115.637164             72           103.20
# 7041     92305  34.167800 -116.864330             11            29.60
# 7042     92308  34.424926 -117.184503             66           105.65
#
#       Churn Score  CLTV   Latitude   Longitude  Total Charges  \
# 0              86  3239  33.964131 -118.272783         108.15
# ...

# %%
data_frame[categorical_columns]
# Out:
#               City  Gender Senior Citizen Partner Dependents Phone Service  \
# 0      Los Angeles    Male             No      No         No           Yes
# 1      Los Angeles  Female             No      No        Yes           Yes
# 2      Los Angeles  Female             No      No        Yes           Yes
# 3      Los Angeles  Female             No     Yes        Yes           Yes
# 4      Los Angeles    Male             No      No        Yes           Yes
# ...            ...     ...            ...     ...        ...           ...
# 7038       Landers  Female             No      No         No           Yes
# 7039      Adelanto    Male             No     Yes        Yes           Yes
# 7040         Amboy  Female             No     Yes        Yes           Yes
# 7041  Angelus Oaks  Female             No     Yes        Yes            No
# 7042  Apple Valley    Male             No      No         No           Yes
#
#         Multiple Lines Internet Service      Online Security  \
# ...

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #2C210D);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #45311AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Split The Data
# </p>

# %%
x_train , x_test , y_train , y_test = algorithm.spliting_data(data_frame , 'Churn Value')

# %%
algorithm.data_information(x_train)
# Out:
#                   Names                                             Values  \
# 0                  City  [San Diego, Jamestown, Littlerock, El Monte, L...
# 1              Zip Code  [92119, 95327, 93543, 91731, 90043, 95562, 952...
# 2              Latitude  [32.802959, 37.84771, 34.505273, 34.079934, 33...
# 3             Longitude  [-117.027095, -120.486589, -117.955054, -118.0...
# 4                Gender                                     [Male, Female]
# 5        Senior Citizen                                          [No, Yes]
# 6               Partner                                          [Yes, No]
# 7            Dependents                                          [No, Yes]
# 8         Tenure Months  [71, 16, 32, 24, 20, 2, 52, 37, 41, 58, 9, 4, ...
# 9         Phone Service                                          [Yes, No]
# 10       Multiple Lines                        [Yes, No, No phone service]
# ...

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Encode The Data
# </p>

# %%
encoding_columns_large = ['City','Total Charges']

# %%
encoding_columns_small
# Out:
# ['Gender',
#  'Senior Citizen',
#  'Partner',
#  'Dependents',
#  'Phone Service',
#  'Paperless Billing',
#  'Multiple Lines',
#  'Internet Service',
#  'Online Security',
#  'Online Backup',
#  'Device Protection',
#  'Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Contract',
#  'Payment Method']

# %%
x_train , x_test = algorithm.ordinal_encoding_data(x_train , x_test , encoding_columns_small)

# %%
x_train , x_test = algorithm.ordinal_encoding_data(x_train , x_test , encoding_columns_large)

# %%
# x_train = pd.get_dummies(x_train , columns = encoding_columns_small)
# x_test = pd.get_dummies(x_test , columns = encoding_columns_small)

# %%
algorithm.data_information(x_train)
# Out:
#                   Names                                             Values  \
# 0                  City  [869.0, 462.0, 541.0, 292.0, 562.0, 835.0, 125...
# 1              Zip Code  [92119, 95327, 93543, 91731, 90043, 95562, 952...
# 2              Latitude  [32.802959, 37.84771, 34.505273, 34.079934, 33...
# 3             Longitude  [-117.027095, -120.486589, -117.955054, -118.0...
# 4                Gender                                         [1.0, 0.0]
# 5        Senior Citizen                                         [0.0, 1.0]
# 6               Partner                                         [1.0, 0.0]
# 7            Dependents                                         [0.0, 1.0]
# 8         Tenure Months  [71, 16, 32, 24, 20, 2, 52, 37, 41, 58, 9, 4, ...
# 9         Phone Service                                         [1.0, 0.0]
# 10       Multiple Lines                                    [2.0, 0.0, 1.0]
# ...

# %%
count_class = y_train.value_counts()
plt.bar(count_class.index, count_class.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class Distribution (Before SMOTE)')
plt.xticks(count_class.index, ['Exited : 0', 'Exited : 1'])
plt.show()

smote = SMOTE(sampling_strategy='minority')
x_train, y_train = smote.fit_resample(x_train, y_train)
# x_train_mms, y_train = smote.fit_resample(x_train_mms, y_train)
# x_train_rs, y_train = smote.fit_resample(x_train_rs, y_train)

# %%
count_class = y_train.value_counts()
plt.bar(count_class.index, count_class.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class Distribution (Before SMOTE)')
plt.xticks(count_class.index, ['Exited : 0', 'Exited : 1'])
plt.show()

print("After SMOTE:\n", y_train.value_counts())
# Out:
# After SMOTE:
#  Churn Value
# 0    4165
# 1    4165
# Name: count, dtype: int64

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #2C210D);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #45311AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Scale The Data
# </p>

# %%
x_train_ss , x_test_ss = algorithm.scaling_data('standard scaler' , data_frame , x_train , x_test , scaling_columns)
x_train_mms , x_test_mms = algorithm.scaling_data('min max scaler' , data_frame , x_train , x_test , scaling_columns)
x_train_rs , x_test_rs = algorithm.scaling_data('robust scaler' , data_frame , x_train , x_test , scaling_columns)

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Feature Selection / Correlation
# </p>

# %%
algorithm.heatmap(x_train_ss)

# %%
algorithm.data_information(data_frame)
# Out:
#                   Names                                             Values  \
# 0                  City  [Los Angeles, Beverly Hills, Huntington Park, ...
# 1              Zip Code  [90003, 90005, 90006, 90010, 90015, 90020, 900...
# 2              Latitude  [33.964131, 34.059281, 34.048013, 34.062125, 3...
# 3             Longitude  [-118.272783, -118.30742, -118.293953, -118.31...
# 4                Gender                                     [Male, Female]
# 5        Senior Citizen                                          [No, Yes]
# 6               Partner                                          [No, Yes]
# 7            Dependents                                          [No, Yes]
# 8         Tenure Months  [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...
# 9         Phone Service                                          [Yes, No]
# 10       Multiple Lines                        [No, Yes, No phone service]
# ...

# %%
numerical_anova , categorical_chi2 = algorithm.correlation(x_train_ss , y_train , data_frame , numerical_columns , categorical_columns)

# %%
numerical_anova
# Out:
#                 Feature       F-Score        P-Value
# 5           Churn Score  11130.359659   0.000000e+00
# 3         Tenure Months   1724.331595   0.000000e+00
# 10  Monthly Charges log    614.532558  5.919804e-131
# 9         Total Charges    594.134926  8.104696e-127
# 4       Monthly Charges    502.096475  4.952233e-108
# 6                  CLTV    158.485410   5.152591e-36
# 2             Longitude      0.089703   7.645630e-01
# 8             Longitude      0.089703   7.645630e-01
# 0              Zip Code      0.068964   7.928578e-01
# 1              Latitude      0.015251   9.017167e-01
# 7              Latitude      0.015251   9.017167e-01

# %%
categorical_chi2
# Out:
#                 Feature  MI_Score
# 16       Payment Method  0.224000
# 8       Online Security  0.200922
# 14             Contract  0.198824
# 7      Internet Service  0.198117
# 11         Tech Support  0.195487
# 10    Device Protection  0.175127
# 9         Online Backup  0.173586
# 12         Streaming TV  0.155927
# 13     Streaming Movies  0.154494
# 1                Gender  0.127825
# 15    Paperless Billing  0.125859
# 3               Partner  0.123958
# 6        Multiple Lines  0.115159
# 4            Dependents  0.095989
# 2        Senior Citizen  0.092948
# 18  left_for_competitor  0.076633
# 20     left_for_service  0.057419
# 5         Phone Service  0.038665
# 17        Total Charges  0.030316
# 0                  City  0.018252
# 19       left_for_price  0.011865

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #2C210D);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #45311AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Best Case
# </p>

# %%
x_train_ss.shape
# Out:
# (8330, 29)

# %%
algorithm.data_information(x_train_ss)
# Out:
#                   Names                                             Values  \
# 0                  City  [869.0, 462.0, 541.0, 292.0, 562.0, 835.0, 125...
# 1              Zip Code  [-0.44209082596769267, 0.5356598597988417, -0....
# 2              Latitude  [-0.8426522590373207, 0.34626724812604237, -0....
# 3             Longitude  [0.7274775738175544, -0.1968850347766427, 0.47...
# 4                Gender  [1.0, 0.0, 0.519081785136218, 0.34124782762615...
# 5        Senior Citizen  [0.0, 1.0, 0.025642065806435688, 0.39882278089...
# 6               Partner  [1.0, 0.0, 0.519081785136218, 0.58017236922733...
# 7            Dependents  [0.0, 1.0, 0.1019694510500131, 0.8985791715507...
# 8         Tenure Months  [1.1363636363636362, -0.11363636363636363, 0.2...
# 9         Phone Service  [1.0, 0.0, 0.4198276307726677, 0.1870142612839...
# 10       Multiple Lines  [2.0, 0.0, 1.0, 0.9618364297275639, 1.04163624...
# ...

# %%
# x_train_ss = x_train_ss.drop('City' , axis=1)
# x_train_ss = x_train_ss.drop('Churn Score' , axis=1)
# x_train_ss = x_train_ss.drop('Tenure Months' , axis=1)
# x_train_ss = x_train_ss.drop('Monthly Charges' , axis=1)

# x_test_ss = x_test_ss.drop('City' , axis=1)
# x_test_ss = x_test_ss.drop('Churn Score' , axis=1)
# x_test_ss = x_test_ss.drop('Tenure Months' , axis=1)
# x_test_ss = x_test_ss.drop('Monthly Charges' , axis=1)

# x_train_mms = x_train_mms.drop('City' , axis=1)
# x_train_mms = x_train_mms.drop('Churn Score' , axis=1)
# x_train_mms = x_train_mms.drop('Tenure Months' , axis=1)
# x_train_mms = x_train_mms.drop('Monthly Charges' , axis=1)

# x_test_mms = x_test_mms.drop('City' , axis=1)
# x_test_mms = x_test_mms.drop('Churn Score' , axis=1)
# x_test_mms = x_test_mms.drop('Tenure Months' , axis=1)
# x_test_mms = x_test_mms.drop('Monthly Charges' , axis=1)

# x_train_rs = x_train_rs.drop('City' , axis=1)
# x_train_rs = x_train_rs.drop('Churn Score' , axis=1)
# x_train_rs = x_train_rs.drop('Tenure Months' , axis=1)
# x_train_rs = x_train_rs.drop('Monthly Charges' , axis=1)

# x_test_rs = x_test_rs.drop('City' , axis=1)
# x_test_rs = x_test_rs.drop('Churn Score' , axis=1)
# x_test_rs = x_test_rs.drop('Tenure Months' , axis=1)
# x_test_rs = x_test_rs.drop('Monthly Charges' , axis=1)

# %% [markdown]
# ## <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #805D2C);
#     font-family: 'Times New Roman', serif;
#     color: #FFD6A0;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 4px;
#     box-shadow: 2px 2px 10px #452F1AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     ML Models
# </p>

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Logistic Regression
# </p>

# %%
"""
Best Logistic Regression : -
Best Parameters: { }
Train Accuracy: _
Test Accuracy: _
"""

# lr_results = algorithm.best_parameters('Logistic Regression' , 'classification' , logistic_regression , LogisticRegression(random_state=42) , x_train_ss , x_test_ss , y_train , y_test)
# Out:
# '\nBest Logistic Regression : -\nBest Parameters: { }\nTrain Accuracy: _\nTest Accuracy: _\n'

# %%
lr_model = LogisticRegression(random_state=42, C=10, penalty='l1', solver='liblinear')

# %%
algorithm.train_test_evaluate('Standard' , x_train_ss , x_test_ss , y_train , y_test , lr_model)
algorithm.evaluate_classification(y_test, lr_model.predict(x_test_ss), labels=[0, 1])
# Out:
# Standard Scaler
# Train Accuracy: 0.9420168067226891
# Test Accuracy: 0.9616749467707594
# Accuracy: 0.9617
# Precision: 0.9620
# Recall: 0.9617
# F1 Score: 0.9618
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      1009
#            1       0.92      0.94      0.93       400
#
#     accuracy                           0.96      1409
#    macro avg       0.95      0.96      0.95      1409
# weighted avg       0.96      0.96      0.96      1409

# %%
algorithm.train_test_evaluate('Min Max' , x_train_mms , x_test_mms , y_train , y_test , lr_model)
algorithm.evaluate_classification(y_test, lr_model.predict(x_test_mms), labels=[0, 1])
# Out:
# Min Max Scaler
# Train Accuracy: 0.9420168067226891
# Test Accuracy: 0.9616749467707594
# Accuracy: 0.9617
# Precision: 0.9620
# Recall: 0.9617
# F1 Score: 0.9618
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      1009
#            1       0.92      0.94      0.93       400
#
#     accuracy                           0.96      1409
#    macro avg       0.95      0.96      0.95      1409
# weighted avg       0.96      0.96      0.96      1409

# %%
algorithm.train_test_evaluate('Robust' , x_train_rs , x_test_rs , y_train , y_test , lr_model)
algorithm.evaluate_classification(y_test, lr_model.predict(x_test_rs), labels=[0, 1])
# Out:
# Robust Scaler
# Train Accuracy: 0.9420168067226891
# Test Accuracy: 0.9616749467707594
# Accuracy: 0.9617
# Precision: 0.9620
# Recall: 0.9617
# F1 Score: 0.9618
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      1009
#            1       0.92      0.94      0.93       400
#
#     accuracy                           0.96      1409
#    macro avg       0.95      0.96      0.95      1409
# weighted avg       0.96      0.96      0.96      1409

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #2C210D);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #45311AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Support Vector Machine
# </p>

# %%
"""
Best SVM : -
Best Parameters: { }
Train Accuracy: _
Test Accuracy: _
"""

# svm_results = algorithm.best_parameters('SVM' , 'classification' , support_vector_machine , SVC(random_state=42) , x_train_ss , x_test_ss , y_train , y_test)
# Out:
# '\nBest SVM : -\nBest Parameters: { }\nTrain Accuracy: _\nTest Accuracy: _\n'

# %%
svm_model = SVC(random_state=42, C=7, kernel='linear')

# %%
# algorithm.train_test_evaluate('Robust' , x_train_rs , x_test_rs , y_train , y_test , svm_model)
# algorithm.evaluate_classification(y_test, svm_model.predict(x_test_rs), labels=[0,1])

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     K Nearest Neighbors
# </p>

# %%
"""
Best KNN : -
Best Parameters: { }
Train Accuracy: _
Test Accuracy: _
"""

# knn_results = algorithm.best_parameters('KNN' , 'classification' , k_nearest_neighbors , KNeighborsClassifier() , x_train_ss , x_test_ss , y_train , y_test)
# Out:
# '\nBest KNN : -\nBest Parameters: { }\nTrain Accuracy: _\nTest Accuracy: _\n'

# %%
knn_model = KNeighborsClassifier(n_neighbors=15, metric='euclidean')

# %%
algorithm.train_test_evaluate('Standard' , x_train_ss , x_test_ss , y_train , y_test , knn_model)
algorithm.evaluate_classification(y_test, knn_model.predict(x_test_ss), labels=[0,1])
# Out:
# Standard Scaler
# Train Accuracy: 0.7831932773109244
# Test Accuracy: 0.6430092264017033
# Accuracy: 0.6430
# Precision: 0.7757
# Recall: 0.6430
# F1 Score: 0.6586
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.56      0.69      1009
#            1       0.44      0.86      0.58       400
#
#     accuracy                           0.64      1409
#    macro avg       0.67      0.71      0.63      1409
# weighted avg       0.78      0.64      0.66      1409

# %%
algorithm.train_test_evaluate('Min Max' , x_train_mms , x_test_mms , y_train , y_test , knn_model)
algorithm.evaluate_classification(y_test, knn_model.predict(x_test_mms), labels=[0,1])
# Out:
# Min Max Scaler
# Train Accuracy: 0.7831932773109244
# Test Accuracy: 0.6430092264017033
# Accuracy: 0.6430
# Precision: 0.7757
# Recall: 0.6430
# F1 Score: 0.6586
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.56      0.69      1009
#            1       0.44      0.86      0.58       400
#
#     accuracy                           0.64      1409
#    macro avg       0.67      0.71      0.63      1409
# weighted avg       0.78      0.64      0.66      1409

# %%
algorithm.train_test_evaluate('Robust' , x_train_rs , x_test_rs , y_train , y_test , knn_model)
algorithm.evaluate_classification(y_test, knn_model.predict(x_test_rs), labels=[0,1])
# Out:
# Robust Scaler
# Train Accuracy: 0.7831932773109244
# Test Accuracy: 0.6430092264017033
# Accuracy: 0.6430
# Precision: 0.7757
# Recall: 0.6430
# F1 Score: 0.6586
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.56      0.69      1009
#            1       0.44      0.86      0.58       400
#
#     accuracy                           0.64      1409
#    macro avg       0.67      0.71      0.63      1409
# weighted avg       0.78      0.64      0.66      1409

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #2C210D);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #45311AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Decision Tree
# </p>

# %%
"""
Best Decision Tree : -
Best Parameters: { }
Train Accuracy: _
Test Accuracy: _
"""

# dt_results = algorithm.best_parameters('Decision Tree' , 'classification' , decision_tree , DecisionTreeClassifier(random_state=42) , x_train_ss , x_test_ss , y_train , y_test)
# Out:
# '\nBest Decision Tree : -\nBest Parameters: { }\nTrain Accuracy: _\nTest Accuracy: _\n'

# %%
dt_model = DecisionTreeClassifier(class_weight='balanced', random_state=42, criterion='entropy', max_depth=50, min_samples_split=4, min_samples_leaf=1)

# %%
algorithm.train_test_evaluate('Standard' , x_train_ss , x_test_ss , y_train , y_test , dt_model)
algorithm.evaluate_classification(y_test, dt_model.predict(x_test_ss), labels=[0,1])
# Out:
# Standard Scaler
# Train Accuracy: 0.9983193277310924
# Test Accuracy: 0.957416607523066
# Accuracy: 0.9574
# Precision: 0.9576
# Recall: 0.9574
# F1 Score: 0.9575
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1009
#            1       0.92      0.93      0.93       400
#
#     accuracy                           0.96      1409
#    macro avg       0.95      0.95      0.95      1409
# weighted avg       0.96      0.96      0.96      1409

# %%
algorithm.train_test_evaluate('Min Max' , x_train_mms , x_test_mms , y_train , y_test , dt_model)
algorithm.evaluate_classification(y_test, dt_model.predict(x_test_mms), labels=[0,1])
# Out:
# Min Max Scaler
# Train Accuracy: 0.9983193277310924
# Test Accuracy: 0.957416607523066
# Accuracy: 0.9574
# Precision: 0.9576
# Recall: 0.9574
# F1 Score: 0.9575
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1009
#            1       0.92      0.93      0.93       400
#
#     accuracy                           0.96      1409
#    macro avg       0.95      0.95      0.95      1409
# weighted avg       0.96      0.96      0.96      1409

# %%
algorithm.train_test_evaluate('Robust' , x_train_rs , x_test_rs , y_train , y_test , dt_model)
algorithm.evaluate_classification(y_test, dt_model.predict(x_test_rs), labels=[0,1])
# Out:
# Robust Scaler
# Train Accuracy: 0.9983193277310924
# Test Accuracy: 0.957416607523066
# Accuracy: 0.9574
# Precision: 0.9576
# Recall: 0.9574
# F1 Score: 0.9575
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1009
#            1       0.92      0.93      0.93       400
#
#     accuracy                           0.96      1409
#    macro avg       0.95      0.95      0.95      1409
# weighted avg       0.96      0.96      0.96      1409

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Random Forest
# </p>

# %%
"""
Best Random Forest : -
Best Parameters: { }
Train Accuracy: _
Test Accuracy: _
"""

# rf_results = algorithm.best_parameters('Random Forest' , 'classification' , random_forest , RandomForestClassifier(random_state=42) , x_train_ss , x_test_ss , y_train , y_test)
# Out:
# '\nBest Random Forest : -\nBest Parameters: { }\nTrain Accuracy: _\nTest Accuracy: _\n'

# %%
rf_model = RandomForestClassifier(class_weight='balanced', random_state=42, criterion='entropy', max_depth=50, min_samples_split=4, min_samples_leaf=1)

# %%
algorithm.train_test_evaluate('Standard' , x_train_ss , x_test_ss , y_train , y_test , rf_model)
algorithm.evaluate_classification(y_test , rf_model.predict(x_test_ss) , labels=[0,1])
# Out:
# Standard Scaler
# Train Accuracy: 0.9998799519807923
# Test Accuracy: 0.9673527324343506
# Accuracy: 0.9674
# Precision: 0.9674
# Recall: 0.9674
# F1 Score: 0.9674
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1009
#            1       0.94      0.94      0.94       400
#
#     accuracy                           0.97      1409
#    macro avg       0.96      0.96      0.96      1409
# weighted avg       0.97      0.97      0.97      1409

# %%
algorithm.train_test_evaluate('Min Max' , x_train_mms , x_test_mms , y_train , y_test , rf_model)
algorithm.evaluate_classification(y_test , rf_model.predict(x_test_mms) , labels=[0,1])
# Out:
# Min Max Scaler
# Train Accuracy: 0.9998799519807923
# Test Accuracy: 0.9673527324343506
# Accuracy: 0.9674
# Precision: 0.9674
# Recall: 0.9674
# F1 Score: 0.9674
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1009
#            1       0.94      0.94      0.94       400
#
#     accuracy                           0.97      1409
#    macro avg       0.96      0.96      0.96      1409
# weighted avg       0.97      0.97      0.97      1409

# %%
algorithm.train_test_evaluate('Robust' , x_train_rs , x_test_rs , y_train , y_test , rf_model)
algorithm.evaluate_classification(y_test , rf_model.predict(x_test_rs) , labels=[0,1])
# Out:
# Robust Scaler
# Train Accuracy: 0.9998799519807923
# Test Accuracy: 0.9673527324343506
# Accuracy: 0.9674
# Precision: 0.9674
# Recall: 0.9674
# F1 Score: 0.9674
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1009
#            1       0.94      0.94      0.94       400
#
#     accuracy                           0.97      1409
#    macro avg       0.96      0.96      0.96      1409
# weighted avg       0.97      0.97      0.97      1409

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #2C210D);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #45311AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     XG Boost
# </p>

# %%
"""
Best XGBoost : -
Best Parameters: { }
Train Accuracy: _
Test Accuracy: _
"""

# xgb_results = algorithm.best_parameters('XGBoost' , 'classification' , gradient_boosting , XGBClassifier(random_state=42) , x_train_ss , x_test_ss , y_train , y_test)
# Out:
# '\nBest XGBoost : -\nBest Parameters: { }\nTrain Accuracy: _\nTest Accuracy: _\n'

# %%
xgb_model = xgb.XGBClassifier(random_forest=42)

# %%
algorithm.train_test_evaluate('Standard' , x_train_ss , x_test_ss , y_train , y_test , xgb_model)
algorithm.evaluate_classification(y_test , xgb_model.predict(x_test_ss) , labels=[0,1])
# Out:
# Standard Scaler
# Train Accuracy: 1.0
# Test Accuracy: 0.9709013484740951
# Accuracy: 0.9709
# Precision: 0.9708
# Recall: 0.9709
# F1 Score: 0.9709
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1009
#            1       0.95      0.94      0.95       400
#
#     accuracy                           0.97      1409
#    macro avg       0.97      0.96      0.96      1409
# weighted avg       0.97      0.97      0.97      1409

# %%
algorithm.train_test_evaluate('Min Max' , x_train_mms , x_test_mms , y_train , y_test , xgb_model)
algorithm.evaluate_classification(y_test , xgb_model.predict(x_test_mms) , labels=[0,1])
# Out:
# Min Max Scaler
# Train Accuracy: 1.0
# Test Accuracy: 0.9709013484740951
# Accuracy: 0.9709
# Precision: 0.9708
# Recall: 0.9709
# F1 Score: 0.9709
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1009
#            1       0.95      0.94      0.95       400
#
#     accuracy                           0.97      1409
#    macro avg       0.97      0.96      0.96      1409
# weighted avg       0.97      0.97      0.97      1409

# %%
algorithm.train_test_evaluate('Robust' , x_train_rs , x_test_rs , y_train , y_test , xgb_model)
algorithm.evaluate_classification(y_test , xgb_model.predict(x_test_rs) , labels=[0,1])
# Out:
# Robust Scaler
# Train Accuracy: 1.0
# Test Accuracy: 0.9709013484740951
# Accuracy: 0.9709
# Precision: 0.9708
# Recall: 0.9709
# F1 Score: 0.9709
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1009
#            1       0.95      0.94      0.95       400
#
#     accuracy                           0.97      1409
#    macro avg       0.97      0.96      0.96      1409
# weighted avg       0.97      0.97      0.97      1409

# %% [markdown]
# ### <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #318462, #0D2C1F);
#     font-family: 'Times New Roman', serif;
#     color: #FFFFFF;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 3px;
#     box-shadow: 2px 2px 10px #1A4530C2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Naive Bias
# </p>

# %%
"""
Best Naive Bias : -
Best Parameters: { }
Train Accuracy: _
Test Accuracy: _
"""

# nb_results = algorithm.best_parameters('Naive Bayes' , 'classification' , naive_bayes_or_GaussianNB , GaussianNB(random_state=42) , x_train_ss , x_test_ss , y_train , y_test)
# Out:
# '\nBest Naive Bias : -\nBest Parameters: { }\nTrain Accuracy: _\nTest Accuracy: _\n'

# %%
nb_model = GaussianNB(var_smoothing=1e-09)

# %%
algorithm.train_test_evaluate('Standard' , x_train_ss , x_test_ss , y_train , y_test , nb_model)
algorithm.evaluate_classification(y_test, nb_model.predict(x_test_ss), labels=[0,1])
# Out:
# Standard Scaler
# Train Accuracy: 0.7307322929171669
# Test Accuracy: 0.9382540809084458
# Accuracy: 0.9383
# Precision: 0.9432
# Recall: 0.9383
# F1 Score: 0.9358
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      1009
#            1       1.00      0.78      0.88       400
#
#     accuracy                           0.94      1409
#    macro avg       0.96      0.89      0.92      1409
# weighted avg       0.94      0.94      0.94      1409

# %%
algorithm.train_test_evaluate('Min Max' , x_train_mms , x_test_mms , y_train , y_test , nb_model)
algorithm.evaluate_classification(y_test, nb_model.predict(x_test_mms), labels=[0,1])
# Out:
# Min Max Scaler
# Train Accuracy: 0.7307322929171669
# Test Accuracy: 0.9382540809084458
# Accuracy: 0.9383
# Precision: 0.9432
# Recall: 0.9383
# F1 Score: 0.9358
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      1009
#            1       1.00      0.78      0.88       400
#
#     accuracy                           0.94      1409
#    macro avg       0.96      0.89      0.92      1409
# weighted avg       0.94      0.94      0.94      1409

# %%
algorithm.train_test_evaluate('Robust' , x_train_rs , x_test_rs , y_train , y_test , nb_model)
algorithm.evaluate_classification(y_test, nb_model.predict(x_test_rs), labels=[0,1])
# Out:
# Robust Scaler
# Train Accuracy: 0.7307322929171669
# Test Accuracy: 0.9382540809084458
# Accuracy: 0.9383
# Precision: 0.9432
# Recall: 0.9383
# F1 Score: 0.9358
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      1009
#            1       1.00      0.78      0.88       400
#
#     accuracy                           0.94      1409
#    macro avg       0.96      0.89      0.92      1409
# weighted avg       0.94      0.94      0.94      1409

# %% [markdown]
# ## <a id='2'></a>
#
# <p style="
#     background: linear-gradient(to right, #805D2C, #318462);
#     font-family: 'Times New Roman', serif;
#     color: #FFD6A0;
#     font-size: 20px;
#     text-align: center;
#     border-radius: 10px;
#     padding: 4px;
#     box-shadow: 2px 2px 10px #452F1AC2;
#     font-weight: bold;
#     letter-spacing: 1px;
# ">
#     Neural Networks
# </p>

# %%
input_dim = x_train_ss.shape[1]
dl_model_ss = Sequential([
    Dense(64, activation='relu', input_shape=(input_dim,)),
    
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(4, activation='relu'),
    
    Dense(1, activation='sigmoid')
])

dl_model_ss.summary()
# input shape = number of features in dataset
# last layer (1 for regression, binary cls, 2 for multiclass)
# Out:
# Model: "sequential_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_163 (Dense)               │ (None, 64)             │         1,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_164 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_165 (Dense)               │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_166 (Dense)               │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_167 (Dense)               │ (None, 1)              │             5 │
# ...

# %%
dl_model_mms = Sequential([
    Dense(64, activation='relu', input_shape=(input_dim,)),
    
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(4, activation='relu'),
    
    Dense(1, activation='sigmoid')
])

dl_model_mms.summary()
# Out:
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_168 (Dense)               │ (None, 64)             │         1,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_169 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_170 (Dense)               │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_171 (Dense)               │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_172 (Dense)               │ (None, 1)              │             5 │
# ...

# %%
dl_model_rs = Sequential([
    Dense(64, activation='relu', input_shape=(input_dim,)),
    
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(4, activation='relu'),
    
    Dense(1, activation='sigmoid')
])

dl_model_rs.summary()
# Out:
# Model: "sequential_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_173 (Dense)               │ (None, 64)             │         1,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_174 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_175 (Dense)               │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_176 (Dense)               │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_177 (Dense)               │ (None, 1)              │             5 │
# ...

# %%
dl_model_ss.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
dl_model_mms.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
dl_model_rs.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history_ss = dl_model_ss.fit(x_train_ss, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6667 - loss: 1.0800 - val_accuracy: 0.9622 - val_loss: 0.2063
# Epoch 2/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8049 - loss: 0.4484 - val_accuracy: 0.9682 - val_loss: 0.1403
# Epoch 3/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8414 - loss: 0.3752 - val_accuracy: 0.9412 - val_loss: 0.2068
# Epoch 4/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8777 - loss: 0.2948 - val_accuracy: 0.9562 - val_loss: 0.1566
# Epoch 5/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8918 - loss: 0.2557 - val_accuracy: 0.9622 - val_loss: 0.1243
# Epoch 6/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9011 - loss: 0.2389 - val_accuracy: 0.9628 - val_loss: 0.1238
# Epoch 7/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9082 - loss: 0.2208 - val_accuracy: 0.9646 - val_loss: 0.1150
# Epoch 8/20
# ...

# %%
history_mms = dl_model_mms.fit(x_train_mms, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5923 - loss: 0.6858 - val_accuracy: 0.0000e+00 - val_loss: 0.7328
# Epoch 2/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6250 - loss: 0.5878 - val_accuracy: 0.0000e+00 - val_loss: 0.7343
# Epoch 3/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7077 - loss: 0.4971 - val_accuracy: 0.9868 - val_loss: 0.6641
# Epoch 4/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7563 - loss: 0.4825 - val_accuracy: 0.9442 - val_loss: 0.6509
# Epoch 5/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4809 - loss: 0.6446 - val_accuracy: 0.9274 - val_loss: 0.7314
# Epoch 6/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5815 - loss: 0.6658 - val_accuracy: 0.0000e+00 - val_loss: 0.7568
# Epoch 7/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6250 - loss: 0.5788 - val_accuracy: 0.0000e+00 - val_loss: 0.7560
# Epoch 8/20
# ...

# %%
history_rs = dl_model_rs.fit(x_train_rs, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5650 - loss: 1.0909 - val_accuracy: 0.0000e+00 - val_loss: 0.7395
# Epoch 2/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6250 - loss: 0.6836 - val_accuracy: 0.0000e+00 - val_loss: 0.7980
# Epoch 3/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6250 - loss: 0.6682 - val_accuracy: 0.0000e+00 - val_loss: 0.8461
# Epoch 4/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6250 - loss: 0.6648 - val_accuracy: 0.0000e+00 - val_loss: 0.8837
# Epoch 5/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6250 - loss: 0.6600 - val_accuracy: 0.0000e+00 - val_loss: 0.9126
# Epoch 6/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6250 - loss: 0.6579 - val_accuracy: 0.0000e+00 - val_loss: 0.9342
# Epoch 7/20
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6250 - loss: 0.6758 - val_accuracy: 0.0000e+00 - val_loss: 0.9378
# Epoch 8/20
# ...

# %%
tr_acc = history_ss.history['accuracy']
tr_loss = history_ss.history['loss']
val_acc = history_ss.history['val_accuracy']
val_loss = history_ss.history['val_loss']

epochs = [i+1 for i in range(len(tr_acc))]

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs, tr_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'g', label='Valid Loss')
plt.title('Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs, tr_acc, 'r', label='Train Accuracy')
plt.plot(epochs, val_acc, 'g', label='Valid Accuracy')
plt.title('Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
tr_acc = history_mms.history['accuracy']
tr_loss = history_mms.history['loss']
val_acc = history_mms.history['val_accuracy']
val_loss = history_mms.history['val_loss']

epochs = [i+1 for i in range(len(tr_acc))]

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs, tr_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'g', label='Valid Loss')
plt.title('Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs, tr_acc, 'r', label='Train Accuracy')
plt.plot(epochs, val_acc, 'g', label='Valid Accuracy')
plt.title('Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
tr_acc = history_rs.history['accuracy']
tr_loss = history_rs.history['loss']
val_acc = history_rs.history['val_accuracy']
val_loss = history_rs.history['val_loss']

epochs = [i+1 for i in range(len(tr_acc))]

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs, tr_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'g', label='Valid Loss')
plt.title('Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs, tr_acc, 'r', label='Train Accuracy')
plt.plot(epochs, val_acc, 'g', label='Valid Accuracy')
plt.title('Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
y_pred_ss = dl_model_ss.predict(x_test_ss)
y_pred_train_ss = dl_model_ss.predict(x_train_ss)
y_pred_ss = (y_pred_ss > 0.5)
y_pred_train_ss = (y_pred_train_ss > 0.5)

print(classification_report(y_test, y_pred_ss))
print(f"Train Accuracy {accuracy_score(y_train , y_pred_train_ss)}")
print(f"Test Accuracy {accuracy_score(y_test , y_pred_ss)}")
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1009
#            1       0.95      0.93      0.94       400
#
#     accuracy                           0.96      1409
#    macro avg       0.96      0.95      0.96      1409
# weighted avg       0.96      0.96      0.96      1409
#
# Train Accuracy 0.9392557022809124
# Test Accuracy 0.964513839602555

# %%
cm_ss = confusion_matrix(y_test, y_pred_ss)
sns.heatmap(cm_ss, annot=True)
plt.show()

# %%
y_pred_mms = dl_model_mms.predict(x_test_mms)
y_pred_train_mms = dl_model_mms.predict(x_train_mms)
y_pred_mms = (y_pred_mms > 0.5)
y_pred_train_mms = (y_pred_train_mms > 0.5)

print(classification_report(y_test, y_pred_mms))
print(f"Train Accuracy {accuracy_score(y_train , y_pred_train_mms)}")
print(f"Test Accuracy {accuracy_score(y_test , y_pred_mms)}")
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      1009
#            1       0.94      0.88      0.91       400
#
#     accuracy                           0.95      1409
#    macro avg       0.95      0.93      0.94      1409
# weighted avg       0.95      0.95      0.95      1409
#
# Train Accuracy 0.9180072028811525
# Test Accuracy 0.9496096522356281

# %%
cm_mms = confusion_matrix(y_test, y_pred_mms)
sns.heatmap(cm_mms, annot=True)
plt.show()

# %%
y_pred_rs = dl_model_rs.predict(x_test_rs)
y_pred_train_rs = dl_model_rs.predict(x_train_rs)
y_pred_rs = (y_pred_rs > 0.5)
y_pred_train_rs = (y_pred_train_rs > 0.5)

print(classification_report(y_test, y_pred_rs))
print(f"Train Accuracy {accuracy_score(y_train , y_pred_train_rs)}")
print(f"Test Accuracy {accuracy_score(y_test , y_pred_rs)}")
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      1009
#            1       0.85      0.96      0.91       400
#
#     accuracy                           0.94      1409
#    macro avg       0.92      0.95      0.93      1409
# weighted avg       0.95      0.94      0.94      1409
#
# Train Accuracy 0.9409363745498199
# Test Accuracy 0.9425124201561391

# %%
cm_rs = confusion_matrix(y_test, y_pred_rs)
sns.heatmap(cm_rs, annot=True)
plt.show()
