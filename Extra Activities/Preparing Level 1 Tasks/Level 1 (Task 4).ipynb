# %% [markdown]
# # **Load and Explore**

# %% [markdown]
# ## **Load Data**

# %% [markdown]
# ## **Shape of Data**

# %% [markdown]
# ## **Columns of Data**

# %% [markdown]
# ## **Data Types of Columns**

# %% [markdown]
# ## **First Five Rows**

# %% [markdown]
# ## **Last Five Rows**

# %% [markdown]
# ## **Information About Data**

# %% [markdown]
# ## **Statisctics Of Data**

# %% [markdown]
# # **Preprocessing**

# %% [markdown]
# **Note : Implement changes to a copy of data**

# %% [markdown]
# ## **Find Numerical Columns (if any)**

# %% [markdown]
# ## **Find Categorical Columns (if any)**

# %% [markdown]
# ## **Find Nominal Columns (if any)**

# %% [markdown]
# ## **Drop Irrelevant Columns**

# %% [markdown]
# ## **Nulls**

# %% [markdown]
# ### **Finding Missing Data**

# %% [markdown]
# ### **Handling Missing Data**

# %% [markdown]
# #### **Remove entire rows with any missing values**

# %% [markdown]
# #### **Remove columns with high percentage of missing values (if any)**

# %% [markdown]
# #### **Fill in the null values with fixed value**

# %% [markdown]
# #### **Implement Measure of Central Tendency** (use the suitable one for each column type)

# %% [markdown]
# ## **Incorrect Data Types**

# %% [markdown]
# ### **Detect Columns with Incorrect Data Types**

# %% [markdown]
# ### **Handle it**

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# ### **Detect Outliers**

# %% [markdown]
# #### **using IQR Method**

# %% [markdown]
# #### **using Z-score Method**

# %% [markdown]
# ### **Handling Outliers (if any)**

# %% [markdown]
# #### **Outliers < lower bound**

# %% [markdown]
# #### **Outliers > upper bound**

# %% [markdown]
# #### **Delete outlier observations entirely**

# %% [markdown]
# ## **Duplicates**

# %% [markdown]
# ### **Detect rows that have duplicates (if any)**

# %% [markdown]
# ### **Drop Duplicates (if any)**

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# ## **Create from existing columns**

# %% [markdown]
# ### **Mathematical Transformation**

# %% [markdown]
# ### **Multiply or combine features**

# %% [markdown]
# ## **Transformation : Two columns that can be converted to one (if any)**

# %% [markdown]
# ## **Extract structured information from categorical column (if any)**
